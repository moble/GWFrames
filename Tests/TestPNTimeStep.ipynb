# %% [markdown]
# This notebook looks at the results for time-step size previous to `PostNewtonian` commit `ae304ed`.  The time step could not always increase again after going through a rough patch.  This has been resolved.

# %%
import GWFrames
import GWFrames.plot

delta = 0.00030765254
chiA = array([ 0.10581191, -0.1167454 , 0.83328752])
chiB = array([-0.22389037, -0.30938855, -0.17084432])
w = GWFrames.PNWaveform('TaylorT4',delta,chiA,chiB,0.005)

# %%
semilogy(w.T()[1:], diff(w.T()))
xlim(108297, 108302);

# %% [markdown]
# I see at least two places where the time-step size has increased!  But why doesn't it increase otherwise???
